# %%
print("hello world")
# Out:
# hello world

# %%
import numpy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import numpy
#
# ModuleNotFoundError: No module named 'numpy'
